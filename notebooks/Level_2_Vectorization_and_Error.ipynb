# %% [markdown]
# # Level 2: NumPy Vectorization and Error Analysis

# %% [markdown]
# Loop vs vectorized ET calculations, timing benchmarks, floating-point precision experiments, and error propagation analysis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
