# %% [markdown]
# # Level 6: AI, Reproducibility and Testing

# %% [markdown]
# Validation, testing, AI use log, reproducibility checklist, requirements, and project packaging.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
